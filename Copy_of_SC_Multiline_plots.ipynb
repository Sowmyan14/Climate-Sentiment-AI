# %%
import matplotlib.pyplot as plt

# %%
#example on multiline plot
epochs = [20,30]
lr = [0.0001,0.001,0.005,0.01,0.1]
A = [0.9868,0.93654,0.879568,0.968745,0.89655]#20 epochs
B = [0.7852,0.89652,0.79652,0.7852,0.8125]#30 epochs


plt.figure(figsize = (5,5))
plt.plot(lr, A, "*-", label = f"Epochs: {epochs[0]}")
plt.plot(lr, B, "*-", label = f"Epochs: {epochs[1]}")
plt.xlabel("Values")
plt.ylabel("Displacement")
plt.xscale("log")
plt.title("Displacement with respective to the values")
plt.legend(loc = "best")
plt.grid(True)
plt.show()

# %%
import pandas as pd
path = "/content/Climate_AI-HPT - Sheet1.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Epochs/Learning_Rate  0.00001  0.0001  0.005  0.001  0.01 Unnamed: 6
# 0                    20    0.765   0.795  0.770  0.750  0.78        NaN
# 1                    30    0.745   0.750  0.760  0.750  0.75        NaN
# 2                    40    0.770   0.780  0.735  0.755  0.76        NaN
# 3                    50    0.755   0.745  0.765  0.770  0.75        NaN
# 4                   100    0.750   0.825  0.800  0.805  0.80

# %%
data.drop('Unnamed: 6', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Epochs/Learning_Rate  0.00001  0.0001  0.005  0.001  0.01
# 0                    20    0.765   0.795  0.770  0.750  0.78
# 1                    30    0.745   0.750  0.760  0.750  0.75
# 2                    40    0.770   0.780  0.735  0.755  0.76
# 3                    50    0.755   0.745  0.765  0.770  0.75
# 4                   100    0.750   0.825  0.800  0.805  0.80

# %%
epochs = list(data["Epochs/Learning_Rate"])
lr = list(data.columns)
lr = lr[1:]
all_acc = []
for index in range(len(epochs)):
  all_acc.append(list(data.iloc[index,1:]))

plt.figure(figsize = (9,9))
for index in range(len(epochs)):
  plt.plot(lr, all_acc[index], label = "Epochs: {}".format(epochs[index]))
plt.xlabel("Learning Rate")
plt.ylabel("Accuracy")
plt.title("Accuracy values with Learning rate and Epochs")
plt.grid(True)
plt.legend(loc = "best")
plt.show()
